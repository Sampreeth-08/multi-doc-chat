# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community
# Out:
# Using Python 3.12.3 environment at: C:\Users\user\OneDrive\Documents\Resume Projects\LLMOPS\.venv
# Audited 6 packages in 983ms

# %%
import os

from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Data Ingestion

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader(r"C:\Users\user\OneDrive\Documents\Resume Projects\LLMOPS\data\Agentic AI.txt", encoding="utf8")
documents = loader.load()

# %%
documents[0].page_content[:500]
# Out:
# 'Agentic AI represents a shift from systems that simply generate text to systems that can autonomously pursue goals. Unlike traditional AI models that act as reactive assistants—responding to a single prompt and then waiting for the next—agentic systems are proactive. They are designed to take a high-level objective, decompose it into a series of logical steps, and execute those steps independently. This transition marks the move from "AI as a consultant" to "AI as a collaborator" that can handle'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)

# %%
text_chunks = text_splitter.split_documents(documents)

# %%
text_chunks
# Out:
# [Document(metadata={'source': 'C:\\Users\\user\\OneDrive\\Documents\\Resume Projects\\LLMOPS\\data\\Agentic AI.txt'}, page_content='Agentic AI represents a shift from systems that simply generate text to systems that can autonomously pursue goals. Unlike traditional AI models that act as reactive assistants—responding to a single'),
#  Document(metadata={'source': 'C:\\Users\\user\\OneDrive\\Documents\\Resume Projects\\LLMOPS\\data\\Agentic AI.txt'}, page_content='to a single prompt and then waiting for the next—agentic systems are proactive. They are designed to take a high-level objective, decompose it into a series of logical steps, and execute those steps'),
# ...

# %%
! uv pip install faiss-cpu
# Out:
# Using Python 3.12.3 environment at: C:\Users\user\OneDrive\Documents\Resume Projects\LLMOPS\.venv
# Audited 1 package in 9ms

# %%
! uv pip install langchain-openai
# Out:
# Using Python 3.12.3 environment at: C:\Users\user\OneDrive\Documents\Resume Projects\LLMOPS\.venv
# Audited 1 package in 20ms

# %%
# Updated import for OpenAI Embeddings
from langchain_openai import OpenAIEmbeddings

# Updated import for FAISS
from langchain_community.vectorstores import FAISS

# %%
embeddings = OpenAIEmbeddings()

# %%
vectorstore = FAISS.from_documents(text_chunks, embeddings)

# %%
query = "What are the key characteristics of Agentic AI?"
docs = vectorstore.similarity_search(query, k=4)

for i, doc in enumerate(docs):
    print(f"Document {i+1}")
    print(doc.page_content)
    print("-"*50)
# Out:
# Document 1
# At its core, agentic AI is characterized by its ability to reason, plan, and use tools. When faced with a complex task, an agent doesn't just predict the next likely word; it creates a mental roadmap
# --------------------------------------------------
# Document 2
# action, agentic AI transforms software from a tool that requires manual operation into an autonomous worker capable of navigating complex, multi-step environments to deliver finished results.
# --------------------------------------------------
# Document 3
# Agentic AI represents a shift from systems that simply generate text to systems that can autonomously pursue goals. Unlike traditional AI models that act as reactive assistants—responding to a single
# --------------------------------------------------
# Document 4
# ...
